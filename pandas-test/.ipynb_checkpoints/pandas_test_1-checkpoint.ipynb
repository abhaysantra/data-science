# %%
import pandas as pd
import numpy as np
import os,sys

# %%
df = pd.read_csv('Admission_Predict_Ver1.1.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# 5             6        330          115                  5  4.5  3.0  9.34
# 6             7        321          109                  3  3.0  4.0  8.20
# 7             8        308          101                  2  3.0  4.0  7.90
# 8             9        302          102                  1  2.0  1.5  8.00
# 9            10        323          108                  3  3.5  3.0  8.60
# 10           11        325          106                  3  3.5  4.0  8.40
# ...

# %%
df_txt = pd.read_csv('Fremont_weather.txt')
df_txt
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58       42           74          22               2.95
# 1    Feb        61       45           78          26               3.02
# 2    Mar        65       48           84          25               2.34
# 3    Apr        67       50           92          28               1.02
# 4    May        71       53           98          35               0.48
# 5    Jun        75       56          107          41               0.11
# 6    Jul        77       58          105          44               0.00
# 7    Aug        77       59          102          43               0.03
# 8    Sep        77       57          103          40               0.17
# 9    Oct        73       54           96          34               0.81
# 10   Nov        64       48           84          30               1.70
# 11   Dec        58       42           73          21               2.56

# %%
df_txt.values, df_txt.columns, df_txt.index
# Out:
# (array([['Jan', 58, 42, 74, 22, 2.95],
#         ['Feb', 61, 45, 78, 26, 3.02],
#         ['Mar', 65, 48, 84, 25, 2.34],
#         ['Apr', 67, 50, 92, 28, 1.02],
#         ['May', 71, 53, 98, 35, 0.48],
#         ['Jun', 75, 56, 107, 41, 0.11],
#         ['Jul', 77, 58, 105, 44, 0.0],
#         ['Aug', 77, 59, 102, 43, 0.03],
#         ['Sep', 77, 57, 103, 40, 0.17],
#         ['Oct', 73, 54, 96, 34, 0.81],
#         ['Nov', 64, 48, 84, 30, 1.7],
#         ['Dec', 58, 42, 73, 21, 2.56]], dtype=object),
#  Index(['month', 'avg_high', 'avg_low', 'record_high', 'record_low',
#         'avg_precipitation'],
#        dtype='object'),
#  RangeIndex(start=0, stop=12, step=1),
#          avg_high    avg_low  record_high  record_low  avg_precipitation
#  count  12.000000  12.000000    12.000000   12.000000          12.000000
#  mean   68.583333  51.000000    91.333333   32.416667           1.265833
#  std     7.366488   6.060303    12.323911    8.240238           1.186396
# ...

# %%
df_txt.describe()
# Out:
#         avg_high    avg_low  record_high  record_low  avg_precipitation
# count  12.000000  12.000000    12.000000   12.000000          12.000000
# mean   68.583333  51.000000    91.333333   32.416667           1.265833
# std     7.366488   6.060303    12.323911    8.240238           1.186396
# min    58.000000  42.000000    73.000000   21.000000           0.000000
# 25%    63.250000  47.250000    82.500000   25.750000           0.155000
# 50%    69.000000  51.500000    94.000000   32.000000           0.915000
# 75%    75.500000  56.250000   102.250000   40.250000           2.395000
# max    77.000000  59.000000   107.000000   44.000000           3.020000

# %%
## sort operation based on ascending descending
df_txt.sort_values('avg_high', ascending= True)
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58       42           74          22               2.95
# 11   Dec        58       42           73          21               2.56
# 1    Feb        61       45           78          26               3.02
# 10   Nov        64       48           84          30               1.70
# 2    Mar        65       48           84          25               2.34
# 3    Apr        67       50           92          28               1.02
# 4    May        71       53           98          35               0.48
# 9    Oct        73       54           96          34               0.81
# 5    Jun        75       56          107          41               0.11
# 6    Jul        77       58          105          44               0.00
# 7    Aug        77       59          102          43               0.03
# 8    Sep        77       57          103          40               0.17

# %%
# getting column values by indexing and slicing
df_txt.avg_low, df_txt['avg_low']
df_txt.shape,df_txt.size
# Out:
# ((12, 6), 72)

# %%
df_txt[2:4]
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 2   Mar        65       48           84          25               2.34
# 3   Apr        67       50           92          28               1.02

# %%
df_txt[['month','avg_low','avg_high']]
# Out:
#    month  avg_low  avg_high
# 0    Jan       42        58
# 1    Feb       45        61
# 2    Mar       48        65
# 3    Apr       50        67
# 4    May       53        71
# 5    Jun       56        75
# 6    Jul       58        77
# 7    Aug       59        77
# 8    Sep       57        77
# 9    Oct       54        73
# 10   Nov       48        64
# 11   Dec       42        58

# %%
# by loc
df_txt.loc[2:4,['avg_low','avg_high']]
df_txt.loc[4,['avg_low','avg_high']]
# Out:
# avg_low     53
# avg_high    71
# Name: 4, dtype: object

# %%
# list comprehension with only if condition
under_10 = [x for x in range(10) if x>5 ]
# list comprehension with if else
under_10 = [x if x > 5 else 0 for x in range(10)]

print('under_10: ' + str(under_10))
# Out:
# under_10: [0, 0, 0, 0, 0, 0, 6, 7, 8, 9]

# %%
# nested loop list comprehension
[[i*j for j in range(1,11)] for i in range(7,9)]
# Out:
# [[7, 14, 21, 28, 35, 42, 49, 56, 63, 70],
#  [8, 16, 24, 32, 40, 48, 56, 64, 72, 80]]
